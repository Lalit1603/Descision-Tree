# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import fetch_california_housing
data = fetch_california_housing()
df = pd.DataFrame(data.data , columns = data.feature_names)
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
df['Price'] = data.target

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Price
# ...

# %%
#fraction of dataset
df = df.sample(frac=0.20)

# %%
df
# Out:
#         MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 19921   3.9250      14.0  4.874494   0.919028       633.0  2.562753     36.32
# 20569   4.1997      17.0  5.732759   1.060345      2866.0  3.088362     38.66
# 12178   2.1549      22.0  5.022459   1.089835      2405.0  2.842790     33.81
# 835     5.0970      33.0  5.664179   1.126866       831.0  3.100746     37.61
# 187     1.8854      30.0  3.798479   1.003802      1011.0  3.844106     37.79
# ...        ...       ...       ...        ...         ...       ...       ...
# 8248    1.8036      42.0  5.459893   1.604278       533.0  2.850267     33.78
# 18363  13.8093       7.0  6.517241   0.896552        84.0  2.896552     37.31
# 18422   5.9359      16.0  5.756024   0.984940      1158.0  3.487952     37.26
# 5554    4.1852      44.0  4.991228   1.000000       497.0  2.179825     33.96
# 18221   4.1544      19.0  4.791667   1.153226      1639.0  2.202957     37.40
#
#        Longitude    Price
# ...

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
X
# Out:
#         MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 19921   3.9250      14.0  4.874494   0.919028       633.0  2.562753     36.32
# 20569   4.1997      17.0  5.732759   1.060345      2866.0  3.088362     38.66
# 12178   2.1549      22.0  5.022459   1.089835      2405.0  2.842790     33.81
# 835     5.0970      33.0  5.664179   1.126866       831.0  3.100746     37.61
# 187     1.8854      30.0  3.798479   1.003802      1011.0  3.844106     37.79
# ...        ...       ...       ...        ...         ...       ...       ...
# 8248    1.8036      42.0  5.459893   1.604278       533.0  2.850267     33.78
# 18363  13.8093       7.0  6.517241   0.896552        84.0  2.896552     37.31
# 18422   5.9359      16.0  5.756024   0.984940      1158.0  3.487952     37.26
# 5554    4.1852      44.0  4.991228   1.000000       497.0  2.179825     33.96
# 18221   4.1544      19.0  4.791667   1.153226      1639.0  2.202957     37.40
#
#        Longitude
# ...

# %%
y
# Out:
# 19921    0.83800
# 20569    1.33400
# 12178    1.46500
# 835      1.88600
# 187      1.37500
#           ...
# 8248     1.75000
# 18363    5.00001
# 18422    2.49500
# 5554     3.03300
# 18221    2.77000
# Name: Price, Length: 4128, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1)

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()

# %%
model
# Out:
# DecisionTreeRegressor()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([2.197, 0.92 , 2.085, ..., 2.281, 1.988, 2.414])

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)#bad r2square
# Out:
# 0.4048426817316573

# %%
parameter = {
    'criterion':['squared_error', 'poissor'],
    'max_depth':[1,2,3,4,5,6,8],
    'splitter':['best','random'],
    'max_features':['sqrt','log2']
}
reg = DecisionTreeRegressor()

# %%
from sklearn.model_selection import GridSearchCV
model =GridSearchCV(reg, param_grid = parameter, cv = 5, scoring = 'neg_mean_squared_error')

# %%
model
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'poissor'],
#                          'max_depth': [1, 2, 3, 4, 5, 6, 8],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='neg_mean_squared_error')

# %%
model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'poissor'],
#                          'max_depth': [1, 2, 3, 4, 5, 6, 8],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='neg_mean_squared_error')

# %%
model.best_params_#using this parameter to good performance
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 6,
#  'max_features': 'log2',
#  'splitter': 'best'}

# %%
final_model = DecisionTreeRegressor(criterion = 'squared_error', max_depth = 6,max_features='log2', splitter='best')
final_model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=6, max_features='log2')

# %%
from sklearn import tree
plt.figure(figsize = (12,10))
tree.plot_tree(final_model,filled = True)
# Out:
# [Text(0.5180084745762712, 0.9285714285714286, 'x[1] <= 50.5\nsquared_error = 1.329\nsamples = 2889\nvalue = 2.077'),
#  Text(0.2711864406779661, 0.7857142857142857, 'x[3] <= 1.097\nsquared_error = 1.257\nsamples = 2681\nvalue = 2.025'),
#  Text(0.13559322033898305, 0.6428571428571429, 'x[2] <= 6.408\nsquared_error = 1.229\nsamples = 1993\nvalue = 2.107'),
#  Text(0.06779661016949153, 0.5, 'x[5] <= 2.662\nsquared_error = 0.879\nsamples = 1701\nvalue = 1.891'),
#  Text(0.03389830508474576, 0.35714285714285715, 'x[0] <= 3.658\nsquared_error = 1.271\nsamples = 629\nvalue = 2.28'),
#  Text(0.01694915254237288, 0.21428571428571427, 'x[2] <= 4.198\nsquared_error = 0.8\nsamples = 363\nvalue = 1.782'),
#  Text(0.00847457627118644, 0.07142857142857142, 'squared_error = 0.848\nsamples = 133\nvalue = 2.189'),
#  Text(0.025423728813559324, 0.07142857142857142, 'squared_error = 0.622\nsamples = 230\nvalue = 1.547'),
# ...

# %%
y_pred = model.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.6072595969208435

# %%
#use complete dataset
#take multiple hyperparameter for tunning
